# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.environ.get("API_KEY")

# %%
city = "des-moines"
state = "ia"
country = "us"
url = f"http://api.openweathermap.org/geo/1.0/direct?q={city},{state},{country}&appid={API_KEY}"
geocoding_res = requests.get(url)
geocoding_res.json()
# Out:
# [{'name': 'Des Moines',
#   'local_names': {'uk': 'Де-Мойн',
#    'he': 'דה מוין',
#    'ru': 'Де-Мойн',
#    'zh': '得梅因',
#    'en': 'Des Moines',
#    'sr': 'Де Мојн',
#    'ta': 'டி மொயின்',
#    'lt': 'De Moinas',
#    'pl': 'Des Moines'},
#   'lat': 41.5868654,
#   'lon': -93.6249494,
#   'country': 'US',
#   'state': 'Iowa'}]

# %%
lat = geocoding_res.json()[0]["lat"]
lon = geocoding_res.json()[0]["lon"]
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=imperial&appid={API_KEY}"
current_weather_res = requests.get(url)
current_weather_res.json()
# Out:
# {'coord': {'lon': -93.625, 'lat': 41.5868},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 84.15,
#   'feels_like': 91.13,
#   'temp_min': 82.45,
#   'temp_max': 86.43,
#   'pressure': 1015,
#   'humidity': 71,
#   'sea_level': 1015,
#   'grnd_level': 983},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 180},
#  'clouds': {'all': 0},
#  'dt': 1751556456,
#  'sys': {'type': 2,
#   'id': 2005004,
#   'country': 'US',
#   'sunrise': 1751539513,
#   'sunset': 1751593921},
#  'timezone': -18000,
#  'id': 4853828,
#  'name': 'Des Moines',
#  'cod': 200}

# %%
url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&units=imperial&appid={API_KEY}"
forecast_res = requests.get(url)
forecast_res.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1751565600,
#    'main': {'temp': 85.44,
#     'feels_like': 91.8,
#     'temp_min': 85.44,
#     'temp_max': 86.31,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 982,
#     'humidity': 65,
#     'temp_kf': -0.48},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 10.09, 'deg': 212, 'gust': 12.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-07-03 18:00:00'},
#   {'dt': 1751576400,
#    'main': {'temp': 89.74,
#     'feels_like': 95.97,
#     'temp_min': 89.74,
#     'temp_max': 92.1,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 982,
#     'humidity': 54,
#     'temp_kf': -1.31},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
# ...

# %%
url = f"http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={lat}&lon={lon}&units=imperial&appid={API_KEY}"
one_call_res = requests.get(url)
one_call_res.json()
# Out:
# {'coord': {'lon': -93.6249, 'lat': 41.5869},
#  'list': [{'main': {'aqi': 1},
#    'components': {'co': 122.63,
#     'no': 0.67,
#     'no2': 1.98,
#     'o3': 52,
#     'so2': 0.74,
#     'pm2_5': 4.94,
#     'pm10': 5.12,
#     'nh3': 1.04},
#    'dt': 1751554800},
#   {'main': {'aqi': 2},
#    'components': {'co': 118.28,
#     'no': 0.32,
#     'no2': 1.19,
#     'o3': 66.2,
#     'so2': 0.99,
#     'pm2_5': 5.15,
#     'pm10': 5.33,
#     'nh3': 0.91},
#    'dt': 1751558400},
#   {'main': {'aqi': 2},
#    'components': {'co': 116.91,
#     'no': 0.21,
#     'no2': 0.88,
#     'o3': 74.81,
#     'so2': 1.14,
#     'pm2_5': 6.05,
#     'pm10': 6.24,
#     'nh3': 0.85},
#    'dt': 1751562000},
#   {'main': {'aqi': 2},
#    'components': {'co': 117.52,
#     'no': 0.16,
#     'no2': 0.78,
#     'o3': 82.35,
#     'so2': 1.3,
#     'pm2_5': 7.25,
#     'pm10': 7.46,
#     'nh3': 0.81},
#    'dt': 1751565600},
#   {'main': {'aqi': 2},
#    'components': {'co': 108.69,
# ...
